# %%
import pandas as pd

# %% [markdown]
# ## Article

# %%
df = pd.read_csv('./article.csv')
df
# Out:
#                                              article
# 0  \r\n\t\t\t\t\t\t\t\t\t\tScraping a website mea...

# %% [markdown]
# ## Page

# %%
df = pd.read_csv('./page.csv')
df
# Out:
#                                               article
# 0   \r\n\t\t\t\t\t\t\t\t\t\tWhen I started web dev...
# 1   \r\n\t\t\t\t\t\t\t\t\t\tjest-each is a small l...
# 2   \r\n\t\t\t\t\t\t\t\t\t\tFor one of Theodo’s cl...
# 3   \r\n\t\t\t\t\t\t\t\t\t\tUsually, we are comple...
# 4   \r\n\t\t\t\t\t\t\t\t\t\tWhy?\nAdding upload fi...
# 5   \r\n\t\t\t\t\t\t\t\t\t\ttl:dr\nTo add a pre-co...
# 6   \r\n\t\t\t\t\t\t\t\t\t\tWhy\nWhat is a Virtual...
# 7   \r\n\t\t\t\t\t\t\t\t\t\tAt some point during t...
# 8   \r\n\t\t\t\t\t\t\t\t\t\tA year ago I was a you...
# 9   \r\n\t\t\t\t\t\t\t\t\t\tIn this tutorial, you ...
# 10  \r\n\t\t\t\t\t\t\t\t\t\tThanks to a new collea...
# 11  \r\n\t\t\t\t\t\t\t\t\t\tStop wasting your time...
# 12  \r\n\t\t\t\t\t\t\t\t\t\tThis is a quick guide ...
# 13  \r\n\t\t\t\t\t\t\t\t\t\tHow to recode Big Brot...

# %% [markdown]
# ## Blog

# %%
df = pd.read_csv('./blog.csv')
df
# Out:
#                                                article
# 0    \r\n\t\t\t\t\t\t\t\t\t\tWhen I started web dev...
# 1    \r\n\t\t\t\t\t\t\t\t\t\tWhy?\nAdding upload fi...
# 2    \r\n\t\t\t\t\t\t\t\t\t\tIn this tutorial, you ...
# 3    \r\n\t\t\t\t\t\t\t\t\t\tStop wasting your time...
# 4    \r\n\t\t\t\t\t\t\t\t\t\tThanks to a new collea...
# 5    \r\n\t\t\t\t\t\t\t\t\t\tWhy\nWhat is a Virtual...
# 6    \r\n\t\t\t\t\t\t\t\t\t\ttl:dr\nTo add a pre-co...
# 7    \r\n\t\t\t\t\t\t\t\t\t\tThis is a quick guide ...
# 8    \r\n\t\t\t\t\t\t\t\t\t\tHow to recode Big Brot...
# 9    \r\n\t\t\t\t\t\t\t\t\t\tAt some point during t...
# 10   \r\n\t\t\t\t\t\t\t\t\t\tA year ago I was a you...
# 11   \r\n\t\t\t\t\t\t\t\t\t\tjest-each is a small l...
# 12   \r\n\t\t\t\t\t\t\t\t\t\tFor one of Theodo’s cl...
# 13   \r\n\t\t\t\t\t\t\t\t\t\tUsually, we are comple...
# 14   \r\n\t\t\t\t\t\t\t\t\t\tAppCenter is a great C...
# 15   \r\n\t\t\t\t\t\t\t\t\t\tThrough my experiences...
# ...

# %% [markdown]
# <hr/>
